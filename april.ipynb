# %% [markdown]
# <a href="https://colab.research.google.com/github/aprilyaeka/pra-pratikum/blob/main/april.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print("DATA DIRI")
print("NAMA                :APRILYA EKA NURFADILAH")
print("NIM                 :2605060015")
print("TEMPAT TANGGAL LAHIR:BOJONEGORO,16 APRIL 2007")
print("ALAMAT              :Ds.klopoduwur,Kec.Banjarejo,Kab.Blora")
print("JENIS KELAMIN       :Perempuan")
print("HOBI                :Menyanyi dan membaca")
# Out:
# DATA DIRI
# NAMA                :APRILYA EKA NURFADILAH
# NIM                 :2605060015
# TEMPAT TANGGAL LAHIR:BOJONEGORO,16 APRIL 2007
# ALAMAT              :Ds.klopoduwur,Kec.Banjarejo,Kab.Blora
# JENIS KELAMIN       :Perempuan
# HOBI                :Menyanyi dan membaca
