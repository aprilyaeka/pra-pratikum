# %% [markdown]
# <a href="https://colab.research.google.com/github/aprilyaeka/pra-pratikum/blob/main/aprilya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("DATA DIRI")
print("NAMA                :APRILYA EKA NURFADILAH")#Menampilkan nama
print("NIM                 :2605060015")#Menampilkan nim
print("TEMPAT TANGGAL LAHIR:BOJONEGORO,16 APRIL 2007")#Menampilkan tempat tanggal lahir
print("ALAMAT              :Ds.klopoduwur,Kec.Banjarejo,Kab.Blora")#Menampilkan alamat
print("JENIS KELAMIN       :Perempuan")#Menampilkan jenis kelamin
print("HOBI                :Menyanyi dan membaca")#Menampilkan hobi
# Out:
# DATA DIRI
# NAMA                :APRILYA EKA NURFADILAH
# NIM                 :2605060015
# TEMPAT TANGGAL LAHIR:BOJONEGORO,16 APRIL 2007
# ALAMAT              :Ds.klopoduwur,Kec.Banjarejo,Kab.Blora
# JENIS KELAMIN       :Perempuan
# HOBI                :Menyanyi dan membaca
